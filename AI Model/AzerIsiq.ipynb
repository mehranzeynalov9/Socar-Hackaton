# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
azerisiq=pd.read_excel('Az Data/iller uzre serfiyyat.xls',skiprows=0).drop(0)

# %%
azerisiq.replace(['...','-'],np.nan,inplace=True)

# %%
azerisiq
# Out:
#      İllər  Elektrik enerjisinin  istehsalı    \
# 1   1920.0                              122.0
# 2   1930.0                              503.9
# 3   1940.0                             1826.3
# 4   1950.0                             2923.5
# 5   1960.0                             6589.0
# 6   1970.0                            12026.7
# 7   1980.0                            15045.2
# 8   1990.0                            23152.6
# 9   1995.0                            17043.6
# 10  2000.0                            18699.1
# 11  2001.0                            18969.1
# 12  2002.0                            18700.6
# 13  2003.0                            21286.3
# 14  2004.0                            21743.2
# 15  2005.0                            22871.5
# 16  2006.0                            24542.7
# 17  2007.0                            21847.0
# 18  2008.0                            21641.6
# 19  2009.0                            18868.3
# ...

# %%
azerisiq.columns
# Out:
# Index(['İllər', 'Elektrik enerjisinin  istehsalı  ',
#        'yanacaqla  işləyən ES və İES-lər', ' SES-lər',
#        'müəssisələrin  daxili  ehtiyaclarının ödənilməsinə  xidmət edən  stansiyalar (yanacaqla  işləyən) ',
#        'generatorlar vasitəsilə ', 'külək  elektrik  stansiyaları',
#        'günəş  elektrik  stansiyaları',
#        'tullantıların yandırılmasından  alınan elektrik enerjisi',
#        'biokütlənin yandırılmasından  alınan elektrik enerjisi'],
#       dtype='object')

# %%
plt.figure(figsize=(14,5))
sns.lineplot(data=azerisiq,x='İllər',y='Elektrik enerjisinin  istehsalı  ')
sns.scatterplot(data=azerisiq,x='İllər',y='Elektrik enerjisinin  istehsalı  ',c='r')
sns.lineplot(data=azerisiq,x='İllər',y='yanacaqla  işləyən ES və İES-lər')
sns.lineplot(data=azerisiq,x='İllər',y='külək  elektrik  stansiyaları')
sns.lineplot(data=azerisiq,x='İllər',y='günəş  elektrik  stansiyaları')
# Out:
# <AxesSubplot:xlabel='İllər', ylabel='Elektrik enerjisinin  istehsalı  '>
